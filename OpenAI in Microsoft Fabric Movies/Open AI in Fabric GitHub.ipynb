# %% [markdown]
# # Let's Start by Scraping our Data
#
# If you want to use your own scraper insert the code below

# %%
#if you don't have a script to use to scrape check out the excel file in the GitHub Rep, load that into your OneLake then ingest it into your Lakehouse, then load the dataframe.

# %% [markdown]
# ## Take a look at the movies

# %%
print(movie_ratings)

# %% [markdown]
# ### Try to write our Datafame to files

# %%
movie_ratings.write.format("CSV").save("Files/MovieInfo")

# %% [markdown]
# ### Understand the Types

# %%
type(movie_ratings)

# %% [markdown]
# ### Converting to a Spark Data Frame

# %%
movieInfo = spark.createDataFrame(movie_ratings)

# %%
type(movieInfo)

# %% [markdown]
# ### Writing to Files

# %%
movieInfo.write.format("CSV").save("Files/movieInfo.csv")

# %% [markdown]
# ### Writing to our Lake House

# %%
movieInfo.write.format("Delta").save("Tables/movieInfo")

# %% [markdown]
# ### YOU CAN PIP!!!

# %%
pip install langchain openai

# %%
pip install azure.keyvault

# %% [markdown]
# ### Key Vault
# I did not replace all of the OS Values reqired with Secrets.  Ran into some issues using this, give it a try, but if it does not work skip to the cell starting with "import os"

# %%
from azure.identity import DefaultAzureCredential
from azure.keyvault.secrets import SecretClient

credential = DefaultAzureCredential()

key_vault_name = ''
KVUri = ""

client = SecretClient(vault_url=KVUri, credential=credential)

api_key = client.get_secret('')

print(api_key.value)

# %%
import os 

os.environ["OPENAI_API_TYPE"] = "azure"
os.environ["OPENAI_API_BASE"] = ""
os.environ["OPENAI_API_VERSION"] = ""
os.environ["OPENAI_API_KEY"] = ""

# %% [markdown]
# ### Let's go to the movies

# %%
movieInfo.show(n=5)

# %%
from langchain.llms import OpenAI
from langchain.llms import AzureOpenAI
from pyspark.sql import SparkSession
from langchain.agents import create_spark_dataframe_agent
from pyspark.sql.functions import *

llm = AzureOpenAI(deployment_name="", model_name="",model_kwargs={"api_type": "azure", "api_version": "2022-12-01"}) 
agent = create_spark_dataframe_agent(llm, movieInfo, verbose=True)

# %% [markdown]
# # Running langchain agents
#
# Now that we have everything instatiated we can use this to call our model with our data frame passed along.  Use the cells below or ask  your own questions!

# %%
agent.run("What movie_name has the highest user_ratings and critic_scores? Display the movie_name and description.")

# %%
agent.run("What movie_name has the most votes and critic_scores? Display the top 10 movie_name and description.")

# %%
agent.run("What are the distinct genre are in the dataframe? Display the generes")

# %%
agent.run("What are the movie_names whose genre contain the words Romance or Drama? Display the movie_names and description.")

# %%
agent.run("Display the description of movie_name Air?")

# %%
agent.run("I like movie_names with a high user_ratings, genre that have Romance or Drama, and descriptions that have sports or Michael Jordan.  What should I watch?")
